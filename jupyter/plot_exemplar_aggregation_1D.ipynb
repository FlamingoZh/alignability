# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import numpy as np
import pandas as pd

# %%
# sns.set_style('darkgrid')  # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)  # fontsize of the axes title
plt.rc('axes', labelsize=18)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=18)  # fontsize of the tick labels
plt.rc('ytick', labelsize=18)  # fontsize of the tick labels
plt.rc('legend', fontsize=18)  # legend fontsize
plt.rc('font', size=18)  # controls default text sizes
# plt.figure(figsize=(10, 6), tight_layout=True)

# %%
def unpack_data(data):
    n_exemplar_list = data["n_exemplar_list"]
    y_list=data["y_list"]
    datasetname = data["datasetname"]
    n_exemplar_max = data["n_exemplar_max"]
    n_sample = data["n_sample"]
    aggregation_mode = data["aggregation_mode"]
    extra_info=data["extra_info"]
    return n_exemplar_list[1:],y_list[1:]

# %%
vg_noun_data_path="../data/dumped_plot_data/vg_noun_visual_20_10.pkl"
vg_noun_data=unpack_data(pickle.load(open(vg_noun_data_path,"rb")))

vg_verb_data_path="../data/dumped_plot_data/vg_verb_visual_20_10.pkl"
vg_verb_data=unpack_data(pickle.load(open(vg_verb_data_path,"rb")))

df1 = pd.DataFrame(np.array(vg_noun_data).transpose(), columns = ['x', 'y'])
df1['word_type']="noun"

df2 = pd.DataFrame(np.array(vg_verb_data).transpose(), columns = ['x', 'y'])
df2['word_type']="verb"

df_visual=pd.concat([df1,df2])

# %%
vg_noun_data_path="../data/dumped_plot_data/vg_noun_bert_language_20_10.pkl"
vg_noun_data=unpack_data(pickle.load(open(vg_noun_data_path,"rb")))

vg_verb_data_path="../data/dumped_plot_data/vg_verb_bert_language_20_10.pkl"
vg_verb_data=unpack_data(pickle.load(open(vg_verb_data_path,"rb")))

df1 = pd.DataFrame(np.array(vg_noun_data).transpose(), columns = ['x', 'y'])
df1['word_type']="noun"

df2 = pd.DataFrame(np.array(vg_verb_data).transpose(), columns = ['x', 'y'])
df2['word_type']="verb"

df_lang=pd.concat([df1,df2])

# %%
fig, ax = plt.subplots(1, figsize=(6, 6))
sns.pointplot(x="x",y="y",data=df_visual,hue="word_type",palette=[sns.color_palette("Paired")[7],sns.color_palette("Paired")[3]],ax=ax)
# plt.setp(g1.lines, alpha=.5) 
# Remove the top and right spines from plot
sns.despine()

ax.legend(loc=4)
ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.05)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set_xlabel("Number of Exemplars Aggregated",fontsize=18)
ax.set_ylabel("Relative Alignment Strength", fontsize=20)
# ax.text(5,1.07,"Visual Aggregation")

plt.tight_layout()
plt.savefig("../figs/vg_visual_agg.png")
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(6, 6))
sns.pointplot(x="x",y="y",data=df_lang,hue="word_type",palette=[sns.color_palette("Paired")[7],sns.color_palette("Paired")[3]],ax=ax)
# plt.setp(g1.lines, alpha=.5) 
# Remove the top and right spines from plot
sns.despine()

ax.legend(loc=4)
ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.05)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set_xlabel("Number of Exemplars Aggregated",fontsize=18)
ax.set_ylabel("Relative Alignment Strength", fontsize=20)
# ax.text(5,1.07,"Visual Aggregation")

plt.tight_layout()
plt.savefig("../figs/vg_lang_agg.png")
plt.show()

# %%
mit_data_path="../data/dumped_plot_data/mit_visual_20_10.pkl"
mit_data=unpack_data(pickle.load(open(mit_data_path,"rb")))

df_mit = pd.DataFrame(np.array(mit_data).transpose(), columns = ['x', 'y'])
df_mit['word_type']="MiT"

# %%
sns.pointplot(x="x",y="y",data=df_lang,hue="word_type",palette=[sns.color_palette("Paired")[7],sns.color_palette("Paired")[3]],ax=ax)
# plt.setp(g1.lines, alpha=.5) 
# Remove the top and right spines from plot
sns.despine()

ax.legend(loc=4)
ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.05)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set_xlabel("Number of Exemplars Aggregated",fontsize=18)
ax.set_ylabel("Relative Alignment Strength", fontsize=20)
# ax.text(5,1.07,"Visual Aggregation")

plt.tight_layout()
plt.savefig("../figs/vg_lang_agg.png")
plt.show()

# %%
fig, ax = plt.subplots(1, figsize=(8, 6))

sns.pointplot(x="x",y="y",hue="word_type",data=df_mit,palette=[sns.color_palette("Paired")[-3]],ax=ax)

sns.despine()

ax.legend(loc=4)
ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.01)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set_xlabel("Number of Exemplars Aggregated",fontsize=18)
ax.set_ylabel("Relative Alignment Strength", fontsize=20)

ax.legend().set_visible(False)

plt.tight_layout()
plt.savefig("../figs/mit_agg.png")
plt.show()

# %%
fig, ax = plt.subplots()

sns.pointplot(x="x",y="y",hue="word_type",data=df_mit,palette=[sns.color_palette("Paired")[-1]])

sns.despine()

ax.legend(loc=4)
ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.01)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set(xlabel='Number of Exemplars Aggregated', ylabel='Relative Alignment Strength')
plt.tight_layout()
plt.savefig("../figs/mit_visual_agg.png")
plt.show()

# %%
# sns.set_style('darkgrid')  # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)  # fontsize of the axes title
plt.rc('axes', labelsize=14)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)  # fontsize of the tick labels
plt.rc('ytick', labelsize=13)  # fontsize of the tick labels
plt.rc('legend', fontsize=13)  # legend fontsize
plt.rc('font', size=13)  # controls default text sizes
plt.figure(figsize=(10, 6), tight_layout=True)

fig, ax = plt.subplots()

sns.pointplot(x="x",y="y",data=df,hue="word_type",palette=[sns.color_palette("Paired")[7],sns.color_palette("Paired")[3]])

sns.despine()

ax.legend(loc=4)

ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.05)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set(xlabel='Number of Exemplars Aggregated', ylabel='Relative Alignment Strength')
plt.tight_layout()
plt.savefig("../figs/vg_language_agg.png")
plt.show()

# %%
imagenet_data_path="../data/dumped_plot_data/imagenet_visual_20_10.pkl"
imagenet_data=unpack_data(pickle.load(open(imagenet_data_path,"rb")))

# %%
df_imagenet = pd.DataFrame(np.array(imagenet_data).transpose(), columns = ['x', 'y'])
df_imagenet['word_type']="ImageNet GloVe"

# %%
# sns.set_style('darkgrid')  # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)  # fontsize of the axes title
plt.rc('axes', labelsize=14)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)  # fontsize of the tick labels
plt.rc('ytick', labelsize=13)  # fontsize of the tick labels
plt.rc('legend', fontsize=13)  # legend fontsize
plt.rc('font', size=13)  # controls default text sizes
plt.figure(figsize=(10, 6), tight_layout=True)

fig, ax = plt.subplots()

sns.pointplot(x="x",y="y",hue="word_type",data=df_imagenet,palette=[sns.color_palette("Paired")[-4]])

sns.despine()

ax.legend(loc=4)
ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.01)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set(xlabel='Number of Exemplars Aggregated', ylabel='Relative Alignment Strength')
plt.tight_layout()
# plt.savefig("../figs/mit_visual_agg.png")
plt.show()

# %%
imagenet_bert_data_path="../data/dumped_plot_data/imagenet_bert_visual_20_10.pkl"
imagenet_bert_data=unpack_data(pickle.load(open(imagenet_bert_data_path,"rb")))

# %%
df_imagenet_bert = pd.DataFrame(np.array(imagenet_bert_data).transpose(), columns = ['x', 'y'])
df_imagenet_bert['word_type']="ImageNet BERT"

# %%
# sns.set_style('darkgrid')  # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)  # fontsize of the axes title
plt.rc('axes', labelsize=14)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)  # fontsize of the tick labels
plt.rc('ytick', labelsize=13)  # fontsize of the tick labels
plt.rc('legend', fontsize=13)  # legend fontsize
plt.rc('font', size=13)  # controls default text sizes
plt.figure(figsize=(10, 6), tight_layout=True)

fig, ax = plt.subplots()

sns.pointplot(x="x",y="y",hue="word_type",data=df_imagenet_bert,palette=[sns.color_palette("Paired")[-3]])

sns.despine()

ax.legend(loc=4)
ax.set_xlim(-1, 21)
ax.set_xticks([0,5,10,15,20])
ax.set_xticklabels([0,5,10,15,20])
ax.set_ylim(0.5, 1.01)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

ax.set(xlabel='Number of Exemplars Aggregated', ylabel='Relative Alignment Strength')
plt.tight_layout()
# plt.savefig("../figs/mit_visual_agg.png")
plt.show()

# %%
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# sns.pointplot(x="x",y="y",data=df_visual,hue="word_type",palette=[sns.color_palette("Paired")[7],sns.color_palette("Paired")[3]],ax=ax1)
# # plt.setp(g1.lines, alpha=.5) 
# # Remove the top and right spines from plot
# sns.despine()

# ax1.legend(loc=4)
# ax1.set_xlim(-1, 21)
# ax1.set_xticks([0,5,10,15,20])
# ax1.set_xticklabels([0,5,10,15,20])
# ax1.set_ylim(0.5, 1.05)
# ax1.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

# ax1.set_xlabel("Number of Exemplars Aggregated",fontsize=18)
# ax1.set_ylabel("Relative Alignment Strength", fontsize=20)
# ax1.text(5,1.07,"Visual Aggregation")

# sns.pointplot(x="x",y="y",data=df_lang,hue="word_type",palette=[sns.color_palette("Paired")[7],sns.color_palette("Paired")[3]],ax=ax2)

# # Remove the top and right spines from plot
# sns.despine()

# ax2.legend(loc=4)
# ax2.set_xlim(-1, 21)
# ax2.set_xticks([0,5,10,15,20])
# ax2.set_xticklabels([0,5,10,15,20])
# ax2.set_ylim(0.5, 1.05)
# ax2.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0])

# ax2.set_xlabel("Number of Exemplars Aggregated",fontsize=18)
# ax2.set_ylabel("", fontsize=16)



# plt.tight_layout()
# plt.savefig("../figs/vg_agg.png")
# plt.show()
